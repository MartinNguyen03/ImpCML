# %%
import matplotlib.pyplot as plt
import numpy as np


# n_values = np.array([9, 12, 15, 18, 24, 30, 45])
# accuracies = np.empty((7))  
# errors = np.empty((7))  



# seed_accuracies = np.empty((7,5))
# seed_accuracies[0] = np.array([0.9584, 0.9595, 0.9574, 0.9571, 0.9570])
# seed_accuracies[1] = np.array([0.9324, 0.9457, 0.9484, 0.9315, 0.9505])
# seed_accuracies[2] = np.array([0.9408, 0.9466, 0.9420, 0.9379, 0.9380])


# for i,nx in enumerate(seed_accuracies):
#     print(i)
#     print(nx)
#     accuracies[i] = np.mean(nx)
#     errors[i] = np.std(nx)


# target_n_values = np.array([9, 12, 15, 18, 24, 30, 45])
# target_accuracies = np.array([0.95, 0.925, 0.90, 0.875, 0.85, 0.80, 0.70])



n_values = np.array([9, 12, 15])
accuracies = np.empty((3))  
errors = np.empty((3))  



seed_accuracies = np.empty((3,5))
seed_accuracies[0] = np.array([0.9584, 0.9595, 0.9574, 0.9571, 0.9570])
seed_accuracies[1] = np.array([0.9324, 0.9457, 0.9484, 0.9315, 0.9505])
seed_accuracies[2] = np.array([0.9408, 0.9466, 0.9420, 0.9379, 0.9380])


for i,nx in enumerate(seed_accuracies):
    print(i)
    print(nx)
    accuracies[i] = np.mean(nx)
    errors[i] = np.std(nx)


target_n_values = np.array([9, 12, 15])
target_accuracies = np.array([0.95, 0.925, 0.90])


font = 18

plt.figure(figsize=(8, 6))

plt.errorbar(n_values, accuracies, yerr=errors, fmt='o-', label='Accuracy', capsize=10, color='blue', lw=4)

plt.plot(target_n_values, target_accuracies, 'r--', label='Target Accuracy', lw=4)

plt.title('', fontsize=font)
plt.xlabel('Feature Dimension of Kryptonite-n (n)', fontsize=font)
plt.ylabel('Accuracy', fontsize=font)
plt.xticks(fontsize=font)
plt.yticks(fontsize=font)


plt.legend(fontsize=font)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

plt.show()
# Out:
# 0
# [0.9584 0.9595 0.9574 0.9571 0.957 ]
# 1
# [0.9324 0.9457 0.9484 0.9315 0.9505]
# 2
# [0.9408 0.9466 0.942  0.9379 0.938 ]

# %%
meow = [0.75, 0.78, 0.81, 0.83, 0.86, 0.88, 0.90]
oink = []
for i in range(len(meow)-1,-1,-1):
    print(i)
    oink.append(meow[i])

print(oink)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0
# [0.9, 0.88, 0.86, 0.83, 0.81, 0.78, 0.75]
